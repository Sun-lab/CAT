# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv', index_col=0)
df
# Out:
#                             CD8Lowery_neg_99g  CD8Lowery_pos_243g  \
# Name
# AAACCTGAGATCCGAG-HN12_post           0.443793            0.227698
# AAACCTGAGGCTAGCA-HN12_post           0.721371            0.396437
# AAACCTGCAGCATGAG-HN12_post           0.673837            0.362820
# AAACCTGGTTCCACAA-HN12_post           0.638706            0.343269
# AAACCTGTCAAAGTAG-HN12_post           0.717915            0.591330
# ...                                       ...                 ...
# TTTGTCAAGGAGTCTG-HN35_post           0.485307            0.238749
# TTTGTCACATCACCCT-HN35_post           0.406315            0.148369
# TTTGTCACATTTGCTT-HN35_post           0.504295            0.166698
# TTTGTCAGTGTTTGTG-HN35_post           0.582515            0.187393
# TTTGTCATCGCGATCG-HN35_post           0.779583            0.411738
#
#                             CD8Oliveira_TTE_100g  CD8Oliveira_pos_74g  \
# Name
# AAACCTGAGATCCGAG-HN12_post              0.161802             0.026723
# AAACCTGAGGCTAGCA-HN12_post              0.150473             0.109185
# AAACCTGCAGCATGAG-HN12_post              0.178524             0.115971
# AAACCTGGTTCCACAA-HN12_post              0.230241             0.127866
# AAACCTGTCAAAGTAG-HN12_post              0.616767             0.500735
# ...                                          ...                  ...
# TTTGTCAAGGAGTCTG-HN35_post              0.067127             0.017005
# TTTGTCACATCACCCT-HN35_post              0.075976            -0.013052
# TTTGTCACATTTGCTT-HN35_post              0.076533            -0.024590
# TTTGTCAGTGTTTGTG-HN35_post              0.047109             0.006026
# TTTGTCATCGCGATCG-HN35_post              0.230139             0.184245
#
#                             CD8Yost_CD8_Exh_100g  CD8_ave_Hanada_pos_27g  \
# Name
# AAACCTGAGATCCGAG-HN12_post              0.149886                0.375481
# AAACCTGAGGCTAGCA-HN12_post              0.238442                0.891787
# AAACCTGCAGCATGAG-HN12_post              0.273848                1.168307
# AAACCTGGTTCCACAA-HN12_post              0.391386                1.437197
# AAACCTGTCAAAGTAG-HN12_post              0.668475                1.898639
# ...                                          ...                     ...
# TTTGTCAAGGAGTCTG-HN35_post              0.172246                0.558664
# TTTGTCACATCACCCT-HN35_post              0.092876                0.636277
# TTTGTCACATTTGCTT-HN35_post              0.112173                0.747165
# TTTGTCAGTGTTTGTG-HN35_post              0.114790                0.683412
# TTTGTCATCGCGATCG-HN35_post              0.464707                1.526299
#
#                             CD8_ave_Hanada_neg_5g  CD8_ave_Oliveira_virus_26g  \
# Name
# AAACCTGAGATCCGAG-HN12_post               1.396201                    0.286678
# AAACCTGAGGCTAGCA-HN12_post               2.218894                    0.309053
# AAACCTGCAGCATGAG-HN12_post               2.021217                    0.177094
# AAACCTGGTTCCACAA-HN12_post               2.579201                    0.301720
# AAACCTGTCAAAGTAG-HN12_post               1.693486                    0.537083
# ...                                           ...                         ...
# TTTGTCAAGGAGTCTG-HN35_post               2.327424                    0.338793
# TTTGTCACATCACCCT-HN35_post               2.139291                    0.125683
# TTTGTCACATTTGCTT-HN35_post               1.313507                    0.187718
# TTTGTCAGTGTTTGTG-HN35_post               2.259007                    0.235427
# TTTGTCATCGCGATCG-HN35_post               2.413879                    0.370234
#
#                             CD4Caushi_Tfh2_66g  CD4Jansen_TermDiff_73g  \
# Name
# AAACCTGAGATCCGAG-HN12_post            0.108374               -0.041285
# AAACCTGAGGCTAGCA-HN12_post            0.063867               -0.003428
# AAACCTGCAGCATGAG-HN12_post            0.193256               -0.037985
# AAACCTGGTTCCACAA-HN12_post            0.267008               -0.037461
# AAACCTGTCAAAGTAG-HN12_post            0.392804                0.047256
# ...                                        ...                     ...
# TTTGTCAAGGAGTCTG-HN35_post           -0.072989                0.041405
# TTTGTCACATCACCCT-HN35_post            0.044088               -0.028024
# TTTGTCACATTTGCTT-HN35_post           -0.095893               -0.049734
# TTTGTCAGTGTTTGTG-HN35_post           -0.040132               -0.056432
# TTTGTCATCGCGATCG-HN35_post            0.486769                0.040342
#
#                             CD4Lowery_neg_37g  CD4Lowery_pos_40g  \
# Name
# AAACCTGAGATCCGAG-HN12_post           0.304796           0.154778
# AAACCTGAGGCTAGCA-HN12_post           0.509551           0.307726
# AAACCTGCAGCATGAG-HN12_post           0.438160           0.294634
# AAACCTGGTTCCACAA-HN12_post           0.446474           0.415380
# AAACCTGTCAAAGTAG-HN12_post           0.659242           0.458528
# ...                                       ...                ...
# TTTGTCAAGGAGTCTG-HN35_post           0.259774           0.026764
# TTTGTCACATCACCCT-HN35_post           0.092855           0.107408
# TTTGTCACATTTGCTT-HN35_post           0.206138          -0.006884
# TTTGTCAGTGTTTGTG-HN35_post           0.387268           0.145689
# TTTGTCATCGCGATCG-HN35_post           0.488174           0.512575
#
#                             CD4Oh_CXCL13_50g  CD4_Hanada_pos_9g  \
# Name
# AAACCTGAGATCCGAG-HN12_post         -0.082794           0.735425
# AAACCTGAGGCTAGCA-HN12_post          0.090825           1.370519
# AAACCTGCAGCATGAG-HN12_post         -0.096258           0.923570
# AAACCTGGTTCCACAA-HN12_post          0.016240           1.371723
# AAACCTGTCAAAGTAG-HN12_post          0.227232           1.612066
# ...                                      ...                ...
# TTTGTCAAGGAGTCTG-HN35_post         -0.016805           0.715035
# TTTGTCACATCACCCT-HN35_post         -0.133106           1.979416
# TTTGTCACATTTGCTT-HN35_post         -0.118342           0.526187
# TTTGTCAGTGTTTGTG-HN35_post         -0.127458           0.692830
# TTTGTCATCGCGATCG-HN35_post          0.345995           1.793063
#
#                             CD4_Hanada_neg_4g
# Name
# AAACCTGAGATCCGAG-HN12_post           3.618632
# AAACCTGAGGCTAGCA-HN12_post           3.226493
# AAACCTGCAGCATGAG-HN12_post           3.617026
# AAACCTGGTTCCACAA-HN12_post           2.976989
# AAACCTGTCAAAGTAG-HN12_post           3.294018
# ...                                       ...
# TTTGTCAAGGAGTCTG-HN35_post           3.346021
# TTTGTCACATCACCCT-HN35_post           1.235212
# TTTGTCACATTTGCTT-HN35_post           2.312230
# TTTGTCAGTGTTTGTG-HN35_post           2.254800
# TTTGTCATCGCGATCG-HN35_post           3.147446
#
# [425770 rows x 15 columns]

# %%
import pandas as pd

predicted_cell_df = pd.read_csv("cell_type.csv")
df = df.merge(predicted_cell_df, left_index=True, right_on='cell_barcode')
#df = df.drop(columns=['cell_barcode'])
df
# Out:
#         CD8Lowery_neg_99g  CD8Lowery_pos_243g  CD8Oliveira_TTE_100g  \
# 0                0.443793            0.227698              0.161802
# 1                0.721371            0.396437              0.150473
# 2                0.673837            0.362820              0.178524
# 3                0.638706            0.343269              0.230241
# 4                0.717915            0.591330              0.616767
# ...                   ...                 ...                   ...
# 425765           0.485307            0.238749              0.067127
# 425766           0.406315            0.148369              0.075976
# 425767           0.504295            0.166698              0.076533
# 425768           0.582515            0.187393              0.047109
# 425769           0.779583            0.411738              0.230139
#
#         CD8Oliveira_pos_74g  CD8Yost_CD8_Exh_100g  CD8_ave_Hanada_pos_27g  \
# 0                  0.026723              0.149886                0.375481
# 1                  0.109185              0.238442                0.891787
# 2                  0.115971              0.273848                1.168307
# 3                  0.127866              0.391386                1.437197
# 4                  0.500735              0.668475                1.898639
# ...                     ...                   ...                     ...
# 425765             0.017005              0.172246                0.558664
# 425766            -0.013052              0.092876                0.636277
# 425767            -0.024590              0.112173                0.747165
# 425768             0.006026              0.114790                0.683412
# 425769             0.184245              0.464707                1.526299
#
#         CD8_ave_Hanada_neg_5g  CD8_ave_Oliveira_virus_26g  CD4Caushi_Tfh2_66g  \
# 0                    1.396201                    0.286678            0.108374
# 1                    2.218894                    0.309053            0.063867
# 2                    2.021217                    0.177094            0.193256
# 3                    2.579201                    0.301720            0.267008
# 4                    1.693486                    0.537083            0.392804
# ...                       ...                         ...                 ...
# 425765               2.327424                    0.338793           -0.072989
# 425766               2.139291                    0.125683            0.044088
# 425767               1.313507                    0.187718           -0.095893
# 425768               2.259007                    0.235427           -0.040132
# 425769               2.413879                    0.370234            0.486769
#
#         CD4Jansen_TermDiff_73g  CD4Lowery_neg_37g  CD4Lowery_pos_40g  \
# 0                    -0.041285           0.304796           0.154778
# 1                    -0.003428           0.509551           0.307726
# 2                    -0.037985           0.438160           0.294634
# 3                    -0.037461           0.446474           0.415380
# 4                     0.047256           0.659242           0.458528
# ...                        ...                ...                ...
# 425765                0.041405           0.259774           0.026764
# 425766               -0.028024           0.092855           0.107408
# 425767               -0.049734           0.206138          -0.006884
# 425768               -0.056432           0.387268           0.145689
# 425769                0.040342           0.488174           0.512575
#
#         CD4Oh_CXCL13_50g  CD4_Hanada_pos_9g  CD4_Hanada_neg_4g  \
# 0              -0.082794           0.735425           3.618632
# 1               0.090825           1.370519           3.226493
# 2              -0.096258           0.923570           3.617026
# 3               0.016240           1.371723           2.976989
# 4               0.227232           1.612066           3.294018
# ...                  ...                ...                ...
# 425765         -0.016805           0.715035           3.346021
# 425766         -0.133106           1.979416           1.235212
# 425767         -0.118342           0.526187           2.312230
# 425768         -0.127458           0.692830           2.254800
# 425769          0.345995           1.793063           3.147446
#
#                       cell_barcode cell_type
# 0       AAACCTGAGATCCGAG-HN12_post       CD4
# 1       AAACCTGAGGCTAGCA-HN12_post       CD4
# 2       AAACCTGCAGCATGAG-HN12_post       CD4
# 3       AAACCTGGTTCCACAA-HN12_post       CD4
# 4       AAACCTGTCAAAGTAG-HN12_post       CD8
# ...                            ...       ...
# 425765  TTTGTCAAGGAGTCTG-HN35_post       CD4
# 425766  TTTGTCACATCACCCT-HN35_post       CD4
# 425767  TTTGTCACATTTGCTT-HN35_post       CD4
# 425768  TTTGTCAGTGTTTGTG-HN35_post       CD4
# 425769  TTTGTCATCGCGATCG-HN35_post       CD4
#
# [425770 rows x 17 columns]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

pos_sigs_CD8 = [
    "CD8Lowery_pos_243g", 
    "CD8Oliveira_TTE_100g", 
    "CD8Oliveira_pos_74g", 
    "CD8Yost_CD8_Exh_100g", 
    "CD8_ave_Hanada_pos_27g"
]
neg_sigs_CD8 = [
    #"CD8Lowery_neg_99g",
    "CD8_ave_Hanada_neg_5g", 
    "CD8_ave_Oliveira_virus_26g"
]

pos_sigs_CD4 = [
    "CD4_Hanada_pos_9g", 
    "CD4Caushi_Tfh2_66g", 
    "CD4Jansen_TermDiff_73g", 
    "CD4Lowery_pos_40g", 
    "CD4Oh_CXCL13_50g"
]
neg_sigs_CD4 = [
    "CD4Lowery_neg_37g", 
    "CD4_Hanada_neg_4g"
]

def classify_cells(df, cell_type, pos_sigs, neg_sigs):
    sub = df[df["cell_type"] == cell_type].copy()
    cols = pos_sigs + neg_sigs

    # z‐score the signatures _within_ this subset
    sub[cols] = sub[cols].apply(zscore)

    # compute mean “pos” and “neg” scores
    sub[f"pos_score_{cell_type}"] = sub[pos_sigs].mean(axis=1)
    sub[f"neg_score_{cell_type}"] = sub[neg_sigs].mean(axis=1)

    # pick cutoffs (here: median)
    pos_cut = sub[f"pos_score_{cell_type}"].median()
    neg_cut = sub[f"neg_score_{cell_type}"].median()

    # classify per cell
    sub[f"cancer_reactive_per_cell_{cell_type}"] = (
        (sub[f"pos_score_{cell_type}"] >  pos_cut) &
        (sub[f"neg_score_{cell_type}"] <  neg_cut)
    )

    return sub

# run it for each cell‐type
cd8_called = classify_cells(df, "CD8", pos_sigs_CD8, neg_sigs_CD8)
cd4_called = classify_cells(df, "CD4", pos_sigs_CD4, neg_sigs_CD4)

df_combined = pd.concat([cd8_called, cd4_called]).sort_index()

# %%
df_combined
# Out:
#         CD8Lowery_neg_99g  CD8Lowery_pos_243g  CD8Oliveira_TTE_100g  \
# 0                0.443793            0.227698              0.161802
# 1                0.721371            0.396437              0.150473
# 2                0.673837            0.362820              0.178524
# 3                0.638706            0.343269              0.230241
# 4                0.717915            2.040847              2.927334
# ...                   ...                 ...                   ...
# 425765           0.485307            0.238749              0.067127
# 425766           0.406315            0.148369              0.075976
# 425767           0.504295            0.166698              0.076533
# 425768           0.582515            0.187393              0.047109
# 425769           0.779583            0.411738              0.230139
#
#         CD8Oliveira_pos_74g  CD8Yost_CD8_Exh_100g  CD8_ave_Hanada_pos_27g  \
# 0                  0.026723              0.149886                0.375481
# 1                  0.109185              0.238442                0.891787
# 2                  0.115971              0.273848                1.168307
# 3                  0.127866              0.391386                1.437197
# 4                  2.573348              2.360942                2.129410
# ...                     ...                   ...                     ...
# 425765             0.017005              0.172246                0.558664
# 425766            -0.013052              0.092876                0.636277
# 425767            -0.024590              0.112173                0.747165
# 425768             0.006026              0.114790                0.683412
# 425769             0.184245              0.464707                1.526299
#
#         CD8_ave_Hanada_neg_5g  CD8_ave_Oliveira_virus_26g  CD4Caushi_Tfh2_66g  \
# 0                    1.396201                    0.286678            0.317584
# 1                    2.218894                    0.309053            0.039741
# 2                    2.021217                    0.177094            0.847473
# 3                    2.579201                    0.301720            1.307879
# 4                   -0.785943                    1.073414            0.392804
# ...                       ...                         ...                 ...
# 425765               2.327424                    0.338793           -0.814603
# 425766               2.139291                    0.125683           -0.083730
# 425767               1.313507                    0.187718           -0.957584
# 425768               2.259007                    0.235427           -0.609488
# 425769               2.413879                    0.370234            2.679770
#
#         CD4Jansen_TermDiff_73g  ...  CD4_Hanada_pos_9g  CD4_Hanada_neg_4g  \
# 0                     0.345890  ...          -0.649763           1.497155
# 1                     1.577521  ...           1.011925           0.824943
# 2                     0.453238  ...          -0.157491           1.494402
# 3                     0.470279  ...           1.015076           0.397238
# 4                     0.047256  ...           1.612066           3.294018
# ...                        ...  ...                ...                ...
# 425765                3.036123  ...          -0.703110           1.029840
# 425766                0.777303  ...           2.605071          -2.588547
# 425767                0.071012  ...          -1.197220          -0.742304
# 425768               -0.146917  ...          -0.761210          -0.840752
# 425769                3.001521  ...           2.117488           0.689440
#
#                       cell_barcode  cell_type  pos_score_CD8 neg_score_CD8  \
# 0       AAACCTGAGATCCGAG-HN12_post        CD4            NaN           NaN
# 1       AAACCTGAGGCTAGCA-HN12_post        CD4            NaN           NaN
# 2       AAACCTGCAGCATGAG-HN12_post        CD4            NaN           NaN
# 3       AAACCTGGTTCCACAA-HN12_post        CD4            NaN           NaN
# 4       AAACCTGTCAAAGTAG-HN12_post        CD8       2.406376      0.143736
# ...                            ...        ...            ...           ...
# 425765  TTTGTCAAGGAGTCTG-HN35_post        CD4            NaN           NaN
# 425766  TTTGTCACATCACCCT-HN35_post        CD4            NaN           NaN
# 425767  TTTGTCACATTTGCTT-HN35_post        CD4            NaN           NaN
# 425768  TTTGTCAGTGTTTGTG-HN35_post        CD4            NaN           NaN
# 425769  TTTGTCATCGCGATCG-HN35_post        CD4            NaN           NaN
#
#        cancer_reactive_per_cell_CD8  pos_score_CD4  neg_score_CD4  \
# 0                               NaN      -0.068511       0.559529
# 1                               NaN       0.940338       0.840756
# 2                               NaN       0.309368       0.960244
# 3                               NaN       0.981176       0.436728
# 4                             False            NaN            NaN
# ...                             ...            ...            ...
# 425765                          NaN       0.184367       0.190129
# 425766                          NaN       0.443899      -2.122322
# 425767                          NaN      -0.750405      -0.857655
# 425768                          NaN      -0.461918      -0.360772
# 425769                          NaN       2.663255       0.708554
#
#        cancer_reactive_per_cell_CD4
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                               NaN
# ...                             ...
# 425765                        False
# 425766                         True
# 425767                        False
# 425768                        False
# 425769                        False
#
# [425770 rows x 23 columns]

# %% [markdown]
# # Visualize scores

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df_combined['pos_score_CD8'], kde=True, color='skyblue')
plt.title('Distribution of Positive Scores CD8')
plt.xlabel('Positive Score')

plt.subplot(1, 2, 2)
sns.histplot(df_combined['neg_score_CD8'], kde=True, color='salmon')
plt.title('Distribution of Negative Scores CD8')
plt.xlabel('Negative Score')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df_combined['pos_score_CD4'], kde=True, color='skyblue')
plt.title('Distribution of Positive Scores CD4')
plt.xlabel('Positive Score')

plt.subplot(1, 2, 2)
sns.histplot(df_combined['neg_score_CD4'], kde=True, color='salmon')
plt.title('Distribution of Negative Scores CD4')
plt.xlabel('Negative Score')

plt.tight_layout()
plt.show()

# %%
# Combine the lists to get all columns
all_sigs_CD8 = pos_sigs_CD8 + neg_sigs_CD8

# Calculate the correlation matrix for the specified columns in the original DataFrame
corr_matrix = df[df.cell_type=='CD8'][all_sigs_CD8].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0, fmt=".2f", 
                      cbar_kws={"label": "Correlation Coefficient"})

plt.title("Correlation Matrix of ssGSEA Scores CD8")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Combine the lists to get all columns
all_sigs_CD4 = pos_sigs_CD4 + neg_sigs_CD4

# Calculate the correlation matrix for the specified columns in the original DataFrame
corr_matrix = df[df.cell_type=='CD4'][all_sigs_CD4].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0, fmt=".2f", 
                      cbar_kws={"label": "Correlation Coefficient"})

plt.title("Correlation Matrix of ssGSEA Scores CD4")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
cluster_df = pd.read_csv("CD4_CD8_clusters.csv", index_col=0)

cluster_df.index.name = "cell_barcode"

cluster_df = cluster_df.reset_index()
cluster_df
# Out:
#                       cell_barcode  cluster_CD4  cluster_CD8
# 0       AAACCTGAGATCCGAG-HN12_post          9.0          NaN
# 1       AAACCTGAGGCTAGCA-HN12_post          2.0          NaN
# 2       AAACCTGCAGCATGAG-HN12_post          2.0          NaN
# 3       AAACCTGGTTCCACAA-HN12_post          2.0          NaN
# 4       AAACCTGTCAAAGTAG-HN12_post          2.0          NaN
# ...                            ...          ...          ...
# 425765  TTTGCGCGTGCACGAA-HN35_post          NaN          3.0
# 425766  TTTGGTTAGTGGGATC-HN35_post          NaN         11.0
# 425767  TTTGGTTCAAGACACG-HN35_post          NaN          2.0
# 425768  TTTGGTTCACACATGT-HN35_post          NaN          2.0
# 425769  TTTGGTTTCTTCGGTC-HN35_post          NaN         11.0
#
# [425770 rows x 3 columns]

# %%
merged_df = cluster_df.merge(df_combined[["cell_barcode", "cell_type", "cancer_reactive_per_cell_CD4","cancer_reactive_per_cell_CD8"]],
                             on="cell_barcode",
                             how="right")

merged_df["cluster"] = merged_df.apply(
    lambda r: r["cluster_CD4"] if r["cell_type"] == "CD4"
              else r["cluster_CD8"],
    axis=1
)

merged_df["cancer_reactive_per_cell"] = merged_df.apply(
    lambda r: r["cancer_reactive_per_cell_CD4"] if r["cell_type"] == "CD4"
              else r["cancer_reactive_per_cell_CD8"],
    axis=1
)

# Group by both cell_type & cluster and compute the fraction reactive
cluster_frac = (
    merged_df
    .groupby(["cell_type", "cluster"])["cancer_reactive_per_cell"]
    .mean()
    .rename("reactive_fraction")
)

# if you want to inspect it as a nice DataFrame:
cluster_frac_df = cluster_frac.reset_index()
cluster_frac_df
# Out:
#    cell_type  cluster  reactive_fraction
# 0        CD4      0.0           0.119886
# 1        CD4      1.0           0.357056
# 2        CD4      2.0           0.234854
# 3        CD4      3.0           0.095665
# 4        CD4      4.0           0.054756
# 5        CD4      5.0           0.378397
# 6        CD4      6.0           0.433566
# 7        CD4      7.0           0.186524
# 8        CD4      8.0           0.071342
# 9        CD4      9.0           0.564300
# 10       CD4     10.0           0.268640
# 11       CD4     11.0           0.002659
# 12       CD4     12.0           0.042123
# 13       CD4     13.0           0.111908
# 14       CD4     14.0           0.301180
# 15       CD4     15.0           0.087833
# 16       CD4     16.0           0.047682
# 17       CD4     17.0           0.126394
# 18       CD4     18.0           0.037037
# 19       CD4     19.0           0.068063
# 20       CD8      0.0           0.011052
# 21       CD8      1.0           0.736534
# 22       CD8      2.0           0.025004
# 23       CD8      3.0           0.592926
# 24       CD8      4.0           0.631724
# 25       CD8      5.0           0.045277
# 26       CD8      6.0           0.505266
# 27       CD8      7.0           0.692633
# 28       CD8      8.0           0.201504
# 29       CD8      9.0           0.532335
# 30       CD8     10.0           0.037799
# 31       CD8     11.0           0.009288
# 32       CD8     12.0           0.000000
# 33       CD8     13.0           0.908358
# 34       CD8     14.0           0.080397
# 35       CD8     15.0           0.000000
# 36       CD8     16.0           0.030625
# 37       CD8     17.0           0.001565
# 38       CD8     18.0           0.000000
# 39       CD8     19.0           0.000000
# 40       CD8     21.0           0.040000

# %%
#  threshold and collect all (cell_type, cluster) pairs above it
threshold = 0.5
reactive_pairs = set(
    cluster_frac[cluster_frac > threshold].index
)

reactive_pairs
# Out:
# {('CD4', 9.0),
#  ('CD8', 1.0),
#  ('CD8', 3.0),
#  ('CD8', 4.0),
#  ('CD8', 6.0),
#  ('CD8', 7.0),
#  ('CD8', 9.0),
#  ('CD8', 13.0)}

# %%
# map back to every cell
merged_df["cancer_reactive_by_cluster"] = merged_df.apply(
    lambda r: True
              if (r["cell_type"], r["cluster"]) in reactive_pairs
              else False,
    axis=1
)

final = merged_df[[
    "cell_barcode", "cell_type", "cluster", 
    "cancer_reactive_per_cell", "cancer_reactive_by_cluster"
]]
final
# Out:
#                       cell_barcode cell_type  cluster  \
# 0       AAACCTGAGATCCGAG-HN12_post       CD4      9.0
# 1       AAACCTGAGGCTAGCA-HN12_post       CD4      2.0
# 2       AAACCTGCAGCATGAG-HN12_post       CD4      2.0
# 3       AAACCTGGTTCCACAA-HN12_post       CD4      2.0
# 4       AAACCTGTCAAAGTAG-HN12_post       CD8      NaN
# ...                            ...       ...      ...
# 425765  TTTGTCAAGGAGTCTG-HN35_post       CD4     13.0
# 425766  TTTGTCACATCACCCT-HN35_post       CD4      4.0
# 425767  TTTGTCACATTTGCTT-HN35_post       CD4     12.0
# 425768  TTTGTCAGTGTTTGTG-HN35_post       CD4      4.0
# 425769  TTTGTCATCGCGATCG-HN35_post       CD4      1.0
#
#         cancer_reactive_per_cell  cancer_reactive_by_cluster
# 0                          False                        True
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 425765                     False                       False
# 425766                      True                       False
# 425767                     False                       False
# 425768                     False                       False
# 425769                     False                       False
#
# [425770 rows x 5 columns]

# %%
df = pd.read_csv('output.csv', index_col=0)
out = df.merge(final, left_index=True, right_on='cell_barcode')
out
# Out:
#         CD8Lowery_neg_99g  CD8Lowery_pos_243g  CD8Oliveira_TTE_100g  \
# 0                0.443793            0.227698              0.161802
# 1                0.721371            0.396437              0.150473
# 2                0.673837            0.362820              0.178524
# 3                0.638706            0.343269              0.230241
# 4                0.717915            0.591330              0.616767
# ...                   ...                 ...                   ...
# 425765           0.485307            0.238749              0.067127
# 425766           0.406315            0.148369              0.075976
# 425767           0.504295            0.166698              0.076533
# 425768           0.582515            0.187393              0.047109
# 425769           0.779583            0.411738              0.230139
#
#         CD8Oliveira_pos_74g  CD8Yost_CD8_Exh_100g  CD8_ave_Hanada_pos_27g  \
# 0                  0.026723              0.149886                0.375481
# 1                  0.109185              0.238442                0.891787
# 2                  0.115971              0.273848                1.168307
# 3                  0.127866              0.391386                1.437197
# 4                  0.500735              0.668475                1.898639
# ...                     ...                   ...                     ...
# 425765             0.017005              0.172246                0.558664
# 425766            -0.013052              0.092876                0.636277
# 425767            -0.024590              0.112173                0.747165
# 425768             0.006026              0.114790                0.683412
# 425769             0.184245              0.464707                1.526299
#
#         CD8_ave_Hanada_neg_5g  CD8_ave_Oliveira_virus_26g  CD4Caushi_Tfh2_66g  \
# 0                    1.396201                    0.286678            0.108374
# 1                    2.218894                    0.309053            0.063867
# 2                    2.021217                    0.177094            0.193256
# 3                    2.579201                    0.301720            0.267008
# 4                    1.693486                    0.537083            0.392804
# ...                       ...                         ...                 ...
# 425765               2.327424                    0.338793           -0.072989
# 425766               2.139291                    0.125683            0.044088
# 425767               1.313507                    0.187718           -0.095893
# 425768               2.259007                    0.235427           -0.040132
# 425769               2.413879                    0.370234            0.486769
#
#         CD4Jansen_TermDiff_73g  CD4Lowery_neg_37g  CD4Lowery_pos_40g  \
# 0                    -0.041285           0.304796           0.154778
# 1                    -0.003428           0.509551           0.307726
# 2                    -0.037985           0.438160           0.294634
# 3                    -0.037461           0.446474           0.415380
# 4                     0.047256           0.659242           0.458528
# ...                        ...                ...                ...
# 425765                0.041405           0.259774           0.026764
# 425766               -0.028024           0.092855           0.107408
# 425767               -0.049734           0.206138          -0.006884
# 425768               -0.056432           0.387268           0.145689
# 425769                0.040342           0.488174           0.512575
#
#         CD4Oh_CXCL13_50g  CD4_Hanada_pos_9g  CD4_Hanada_neg_4g  \
# 0              -0.082794           0.735425           3.618632
# 1               0.090825           1.370519           3.226493
# 2              -0.096258           0.923570           3.617026
# 3               0.016240           1.371723           2.976989
# 4               0.227232           1.612066           3.294018
# ...                  ...                ...                ...
# 425765         -0.016805           0.715035           3.346021
# 425766         -0.133106           1.979416           1.235212
# 425767         -0.118342           0.526187           2.312230
# 425768         -0.127458           0.692830           2.254800
# 425769          0.345995           1.793063           3.147446
#
#                       cell_barcode cell_type  cluster  \
# 0       AAACCTGAGATCCGAG-HN12_post       CD4      9.0
# 1       AAACCTGAGGCTAGCA-HN12_post       CD4      2.0
# 2       AAACCTGCAGCATGAG-HN12_post       CD4      2.0
# 3       AAACCTGGTTCCACAA-HN12_post       CD4      2.0
# 4       AAACCTGTCAAAGTAG-HN12_post       CD8      NaN
# ...                            ...       ...      ...
# 425765  TTTGTCAAGGAGTCTG-HN35_post       CD4     13.0
# 425766  TTTGTCACATCACCCT-HN35_post       CD4      4.0
# 425767  TTTGTCACATTTGCTT-HN35_post       CD4     12.0
# 425768  TTTGTCAGTGTTTGTG-HN35_post       CD4      4.0
# 425769  TTTGTCATCGCGATCG-HN35_post       CD4      1.0
#
#         cancer_reactive_per_cell  cancer_reactive_by_cluster
# 0                          False                        True
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ...                          ...                         ...
# 425765                     False                       False
# 425766                      True                       False
# 425767                     False                       False
# 425768                     False                       False
# 425769                     False                       False
#
# [425770 rows x 20 columns]

# %%
out.to_csv("cell_meta_data.csv", index=False)

# %%
out["cancer_reactive"] = (
    out["cancer_reactive_per_cell"] 
  & out["cancer_reactive_by_cluster"]
)
out.set_index("cell_barcode", inplace=True)

# %%
out[['barcode', 'sample', 'timepoint']] = out.index.to_series().str.extract(
    r'^([^-]+)-([^_]+)_(.+)$'
)

# -----------------------------------------------------------
# Compute proportion of cancer-reactive T cells by sample/timepoint
# -----------------------------------------------------------
# 'cancer_reactive' is a boolean column: True = reactive, False = not reactive
# Group by sample and timepoint, then compute the mean (which = proportion True).
prop_df = (
    out[out.cell_type=='CD8']
    .groupby(['sample', 'timepoint'])['cancer_reactive']
    .mean()  # This yields the fraction of T cells that are cancer-reactive
    .reset_index(name='proportion_reactive')
)

# # -----------------------------------------------------------
# # Keep only samples that have both pre and post measurements
# # -----------------------------------------------------------
# # First, see how many timepoints each sample has:
sample_counts = prop_df['sample'].value_counts()
# Keep only those with 2 or more timepoints (pre + post)
samples_with_prepost = sample_counts[sample_counts >= 2].index
prop_df = prop_df[prop_df['sample'].isin(samples_with_prepost)]

# Also, filter out any timepoints that are not 'pre' or 'post'
prop_df = prop_df[prop_df['timepoint'].isin(['pre', 'post'])]

prop_df
# Out:
#    sample timepoint  proportion_reactive
# 0    HN01      post             0.114719
# 1    HN01       pre             0.111818
# 2    HN02      post             0.356649
# 3    HN02       pre             0.094895
# 4    HN03      post             0.559674
# 5    HN03       pre             0.246154
# 6    HN04      post             0.381717
# 7    HN04       pre             0.310069
# 8    HN05      post             0.348259
# 9    HN05       pre             0.766146
# 13   HN09      post             0.041009
# 14   HN09       pre             0.061693
# 15   HN10      post             0.036123
# 16   HN10       pre             0.210870
# 17   HN11      post             0.627440
# 18   HN11       pre             0.597077
# 19   HN12      post             0.487844
# 20   HN12       pre             0.420880
# 22   HN14      post             0.130334
# 23   HN14       pre             0.065375
# 25   HN16      post             0.028360
# 26   HN16       pre             0.176796
# 29   HN19      post             0.118366
# 30   HN19       pre             0.387482
# 31   HN20      post             0.368984
# 32   HN20       pre             0.090226
# 33   HN21      post             0.125738
# 34   HN21       pre             0.025745
# 35   HN22      post             0.539980
# 36   HN22       pre             0.015478
# 37   HN23      post             0.186346
# 38   HN23       pre             0.067725
# 39   HN24      post             0.115664
# 40   HN24       pre             0.017817
# 42   HN26      post             0.132676
# 43   HN26       pre             0.362257
# 44   HN27      post             0.657933
# 45   HN27       pre             0.599760
# 46   HN28      post             0.291236
# 47   HN28       pre             0.453413
# 51   HN32      post             0.059924
# 52   HN32       pre             0.220835
# 53   HN33      post             0.333122
# 54   HN33       pre             0.336898
# 55   HN34      post             0.056974
# 56   HN34       pre             0.068334
# 57   HN35      post             0.126091
# 58   HN35       pre             0.058973

# %%
# -----------------------------------------------------------
# Visualize a simple comparison: bar chart of pre vs post
# -----------------------------------------------------------
plt.figure(figsize=(8, 5))
sns.barplot(
    data=prop_df,
    x='sample',
    y='proportion_reactive',
    hue='timepoint',
    palette='Set2'
)

plt.title("Proportion of Cancer-Reactive CD8 T Cells: Pre vs. Post")
plt.ylabel("Proportion Cancer-Reactive")
plt.xlabel("Sample")
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)  # proportion ranges from 0 to 1
plt.tight_layout()
plt.legend(title="Timepoint")
plt.show()

# %%
# -----------------------------------------------------------
# Compute proportion of cancer-reactive T cells by sample/timepoint
# -----------------------------------------------------------
# 'cancer_reactive' is a boolean column: True = reactive, False = not reactive
# Group by sample and timepoint, then compute the mean (which = proportion True).
prop_df_CD4 = (
    out[out.cell_type=='CD4']
    .groupby(['sample', 'timepoint'])['cancer_reactive']
    .mean()  # This yields the fraction of T cells that are cancer-reactive
    .reset_index(name='proportion_reactive')
)

# # -----------------------------------------------------------
# # Keep only samples that have both pre and post measurements
# # -----------------------------------------------------------
# # First, see how many timepoints each sample has:
sample_counts = prop_df_CD4['sample'].value_counts()
# Keep only those with 2 or more timepoints (pre + post)
samples_with_prepost = sample_counts[sample_counts >= 2].index
prop_df_CD4 = prop_df_CD4[prop_df_CD4['sample'].isin(samples_with_prepost)]

# Also, optionally filter out any timepoints that are not 'pre' or 'post'
prop_df_CD4 = prop_df_CD4[prop_df_CD4['timepoint'].isin(['pre', 'post'])]

# %%
# -----------------------------------------------------------
# Visualize a simple comparison: bar chart of pre vs post
# -----------------------------------------------------------
plt.figure(figsize=(8, 5))
sns.barplot(
    data=prop_df_CD4,
    x='sample',
    y='proportion_reactive',
    hue='timepoint',
    palette='Set2'
)

plt.title("Proportion of Cancer-Reactive CD4 T Cells: Pre vs. Post")
plt.ylabel("Proportion Cancer-Reactive")
plt.xlabel("Sample")
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)  # proportion ranges from 0 to 1
plt.tight_layout()
plt.legend(title="Timepoint")
plt.show()
