# %% [markdown]
# # Parameters
# ## Main parameters

# %%
cell_type    = 'CD8'
learn_rate   = 1e-3
batch_size   = 32
test_study   = 'Chen_2024'

# %%
# Parameters
cell_type = "CD8"
learn_rate = 0.001
batch_size = 32
test_study = "Zheng_2021"

# %% [markdown]
# ## Additional parameters

# %%
data_dir         = "/Users/wsun/research/CAT/data/"
results_dir      = "classification_result/"
max_epochs       = 20
model_patience   = 10
validating_frac  = 0.10
classify_layers  = []
encode_layers    = [128 , 32]
bottle_size      = 8
adj_class_weight = True

# %% [markdown]
# # Load modules and define functions
# ## Imports

# %%
import os
import argparse
import itertools
import random
import seaborn as sns
import scanpy as sc
import scipy.sparse as sp

from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
import keras
from keras import optimizers
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.models import Model
from keras.callbacks import EarlyStopping, LearningRateScheduler

import math
import numpy as np
import pandas as pd
import matplotlib
np.random.seed(42)
tf.random.set_seed(42)
matplotlib.use("Agg")
import matplotlib.pyplot as plt

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Plot classification function and save classification results

# %%
def plot_classification(m1, start, plot_path):
    # plot the training loss and accuracy
    end = len(m1.history['classification_accuracy'])
    N   = np.arange(start, end)
    s   = slice(start,end)

    plt.style.use("ggplot")
    plt.figure(figsize=(4, 3), dpi=300)

    plt.plot(N, (m1.history["classification_accuracy"][s]), label="train_accuracy")
    plt.plot(N, (m1.history["val_classification_accuracy"][s]), label="val_accuracy")

    plt.xlabel("Epoch #")
    plt.ylabel("Classification Accuracy")
    plt.legend()
    plt.subplots_adjust(left=0.25, right=0.98, top=0.98, bottom=0.2)
    plt.savefig(plot_path)
    plt.close()


def table_save_classification(m1, start, file_path):
    end = len(m1.history['classification_accuracy'])
    epochs = range(start, end)
    train_losses = m1.history['classification_accuracy'][start:end]
    val_losses = m1.history['val_classification_accuracy'][start:end]

    # Write the table to the file
    with open(file_path, 'w') as f:
        f.write("Epoch\tTrain_Acc\tVal_Acc\n")  # Header row
        for epoch, train_loss, val_loss in zip(epochs, train_losses, val_losses):
            f.write(f"{epoch}\t{train_loss:.4f}\t{val_loss:.4f}\n")

# %% [markdown]
# # Define model
# ## Model configuration

# %%
config = 'en_'
for size in encode_layers:
  config += str(size) + '_'

config += 'bn_' + str(bottle_size) + '_cl_'

for size in classify_layers:
  config += str(size) + '_'


config = config + 'bs_' + str(batch_size) + '_lr_' + str(learn_rate)
config = config + '_e_' + str(max_epochs)
config
# Out:
# 'en_128_32_bn_8_cl_bs_32_lr_0.001_e_20'

# %% [markdown]
# ## Read in data

# %%
adata = sc.read_h5ad(data_dir + cell_type + "_combined_filtered.h5ad")

print("Count Data:")
print(adata.X.shape)
print(adata.X[:5,:4])
print()
print("Meta Data:")
print(adata.obs.shape)
pd.set_option('display.max_columns', None)  # show all columns
print(adata.obs[:5])
print()
# Out:
# Count Data:
# (371010, 6256)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (5, 4)>
#   Coords	Values
#   (0, 0)	1.0
#   (1, 0)	1.0
#   (2, 3)	2.0
#   (3, 3)	1.0
#   (4, 3)	1.0
#
# Meta Data:
# (371010, 45)
#                                         study2  n_genes_by_counts  \
# P309-GACACGCGTGGTAACG-1-Liu_2025      Liu_2025               1048
# P309-AGCTTGATCGACAGCC-1-Liu_2025      Liu_2025               1116
# P309-GGGTTGCCAAATACAG-1-Liu_2025      Liu_2025               1308
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022    Liu_2022                967
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  Chow_2023               2077
#
#                                      total_counts       TRB_cdr3 TRB_v_gene  \
# P309-GACACGCGTGGTAACG-1-Liu_2025           2234.0  CAAADRGQDTQYF     TRBV19
# P309-AGCTTGATCGACAGCC-1-Liu_2025           2935.0  CAAADRGQDTQYF     TRBV19
# P309-GGGTTGCCAAATACAG-1-Liu_2025           2119.0  CAAADRGQDTQYF     TRBV19
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022         1585.0  CAAAETSNQPQHF      TRBV2
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023        7606.0   CAAAGIYNEQFF    TRBV6-2
#
#                                             TRA_cdr3    TRA_v_gene  \
# P309-GACACGCGTGGTAACG-1-Liu_2025       CAADNQAGTALIF      TRAV13-1
# P309-AGCTTGATCGACAGCC-1-Liu_2025       CAADNQAGTALIF      TRAV13-1
# P309-GGGTTGCCAAATACAG-1-Liu_2025       CAVPQEGNNRLAF       TRAV8-6
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022    CARPLGGSNYKLTF        TRAV16
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  CAYRRSASGTYKYIF  TRAV38-2/DV8
#
#                                                                                  clone  \
# P309-GACACGCGTGGTAACG-1-Liu_2025           TRAV13-1_CAADNQAGTALIF_TRBV19_CAAADRGQDTQYF
# P309-AGCTTGATCGACAGCC-1-Liu_2025           TRAV13-1_CAADNQAGTALIF_TRBV19_CAAADRGQDTQYF
# P309-GGGTTGCCAAATACAG-1-Liu_2025            TRAV8-6_CAVPQEGNNRLAF_TRBV19_CAAADRGQDTQYF
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022           TRAV16_CARPLGGSNYKLTF_TRBV2_CAAAETSNQPQHF
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  TRAV38-2/DV8_CAYRRSASGTYKYIF_TRBV6-2_CAAAGIYNEQFF
#
#                                                        cell_id      study  \
# P309-GACACGCGTGGTAACG-1-Liu_2025       P309-GACACGCGTGGTAACG-1   Liu_2025
# P309-AGCTTGATCGACAGCC-1-Liu_2025       P309-AGCTTGATCGACAGCC-1   Liu_2025
# P309-GGGTTGCCAAATACAG-1-Liu_2025       P309-GGGTTGCCAAATACAG-1   Liu_2025
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022   P25.ut.AGAGCGAAGCTAGTTC-1   Liu_2022
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  CCCAATCTCGTCCGTT-1_PEM6C1  Chow_2023
#
#                                     cancer_type          Patient      Sample  \
# P309-GACACGCGTGGTAACG-1-Liu_2025          NSCLC     Liu2025_P309        P309
# P309-AGCTTGATCGACAGCC-1-Liu_2025          NSCLC     Liu2025_P309        P309
# P309-GGGTTGCCAAATACAG-1-Liu_2025          NSCLC     Liu2025_P309        P309
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022        NSCLC      Liu2022_P25     P25.pre
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023          EC  Chow2023_PEM6C1  GSM6514159
#
#                                      Treatment Tissue  \
# P309-GACACGCGTGGTAACG-1-Liu_2025     anti-PD-1  Tumor
# P309-AGCTTGATCGACAGCC-1-Liu_2025     anti-PD-1  Tumor
# P309-GGGTTGCCAAATACAG-1-Liu_2025     anti-PD-1  Tumor
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022   anti-PD-1  Tumor
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  anti-PD-1  Blood
#
#                                      study_specific_CR_per_cell  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                          False
# P309-AGCTTGATCGACAGCC-1-Liu_2025                          False
# P309-GGGTTGCCAAATACAG-1-Liu_2025                          False
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                        False
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                       False
#
#                                      study_specific_CR_by_cluster  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                            False
# P309-AGCTTGATCGACAGCC-1-Liu_2025                            False
# P309-GGGTTGCCAAATACAG-1-Liu_2025                            False
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                          False
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                         False
#
#                                                 barcode TRA_j_gene TRB_j_gene  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                      1     TRAJ15    TRBJ2-3
# P309-AGCTTGATCGACAGCC-1-Liu_2025                      1     TRAJ15    TRBJ2-3
# P309-GGGTTGCCAAATACAG-1-Liu_2025                      1      TRAJ7    TRBJ2-3
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022   AGAGCGAAGCTAGTTC-1     TRAJ53    TRBJ1-5
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023  CCCAATCTCGTCCGTT-1     TRAJ40    TRBJ2-1
#
#                                      TRA_nUMI  TRB_nUMI  CD8_Lowery_pos_243g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025          NaN       NaN            -1.409159
# P309-AGCTTGATCGACAGCC-1-Liu_2025          NaN       NaN            -1.478880
# P309-GGGTTGCCAAATACAG-1-Liu_2025          NaN       NaN            -1.039742
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022        3.0       3.0            -1.643940
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023       9.0      17.0             0.922358
#
#                                      CD8_Oliveira_TTE_100g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                 -0.274220
# P309-AGCTTGATCGACAGCC-1-Liu_2025                 -1.200511
# P309-GGGTTGCCAAATACAG-1-Liu_2025                  0.040170
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022               -1.518571
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023               0.170145
#
#                                      CD8_Oliveira_pos_74g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                -0.509829
# P309-AGCTTGATCGACAGCC-1-Liu_2025                -1.336684
# P309-GGGTTGCCAAATACAG-1-Liu_2025                -0.388673
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022              -0.303975
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023             -0.421592
#
#                                      CD8_Yost_CD8_Exh_100g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                 -1.141852
# P309-AGCTTGATCGACAGCC-1-Liu_2025                 -1.260159
# P309-GGGTTGCCAAATACAG-1-Liu_2025                 -0.822104
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022               -0.986047
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023              -0.364514
#
#                                      CD8_ave_Hanada_pos_27g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                  -0.271678
# P309-AGCTTGATCGACAGCC-1-Liu_2025                  -1.141971
# P309-GGGTTGCCAAATACAG-1-Liu_2025                  -1.170673
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                -0.850075
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023               -0.948168
#
#                                      CD8_ave_Hanada_neg_5g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                 -0.067477
# P309-AGCTTGATCGACAGCC-1-Liu_2025                  2.323945
# P309-GGGTTGCCAAATACAG-1-Liu_2025                 -0.920151
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022               -0.735291
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023               1.185236
#
#                                      CD8_ave_Oliveira_virus_26g  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                       0.269658
# P309-AGCTTGATCGACAGCC-1-Liu_2025                       1.813296
# P309-GGGTTGCCAAATACAG-1-Liu_2025                       4.333656
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                     2.946838
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                    0.896645
#
#                                           study_clone_id  study_clone_number  \
# P309-GACACGCGTGGTAACG-1-Liu_2025     P309_clonetype_2086                 2.0
# P309-AGCTTGATCGACAGCC-1-Liu_2025     P309_clonetype_2086                 2.0
# P309-GGGTTGCCAAATACAG-1-Liu_2025     P309_clonetype_1842                 1.0
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                   NaN                 NaN
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023        clonotype1165                 NaN
#
#                                      pos_score_CD8  neg_score_CD8  \
# P309-GACACGCGTGGTAACG-1-Liu_2025         -0.721348       0.101090
# P309-AGCTTGATCGACAGCC-1-Liu_2025         -1.283641       2.068620
# P309-GGGTTGCCAAATACAG-1-Liu_2025         -0.676204       1.706753
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022       -1.060522       1.105773
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023      -0.128354       1.040940
#
#                                      cancer_reactive_per_cell  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                        False
# P309-AGCTTGATCGACAGCC-1-Liu_2025                        False
# P309-GGGTTGCCAAATACAG-1-Liu_2025                        False
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                      False
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                     False
#
#                                      cancer_reactive  total_cells_patient  \
# P309-GACACGCGTGGTAACG-1-Liu_2025               False                 1214
# P309-AGCTTGATCGACAGCC-1-Liu_2025               False                 1214
# P309-GGGTTGCCAAATACAG-1-Liu_2025               False                 1214
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022             False                 1156
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023            False                 1658
#
#                                      clone_number_per_patient  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                            2
# P309-AGCTTGATCGACAGCC-1-Liu_2025                            2
# P309-GGGTTGCCAAATACAG-1-Liu_2025                            1
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                          1
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                         1
#
#                                      clone_number_total  clone_n_patient  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                      2                1
# P309-AGCTTGATCGACAGCC-1-Liu_2025                      2                1
# P309-GGGTTGCCAAATACAG-1-Liu_2025                      1                1
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                    1                1
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                   1                1
#
#                                      clone_number_per_patient_median  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                                 2.0
# P309-AGCTTGATCGACAGCC-1-Liu_2025                                 2.0
# P309-GGGTTGCCAAATACAG-1-Liu_2025                                 1.0
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                               1.0
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                              1.0
#
#                                      clone_freq_per_patient TRA_antigen  \
# P309-GACACGCGTGGTAACG-1-Liu_2025                   0.001647         NaN
# P309-AGCTTGATCGACAGCC-1-Liu_2025                   0.001647         NaN
# P309-GGGTTGCCAAATACAG-1-Liu_2025                   0.000824         NaN
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022                 0.000865         NaN
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023                0.000603         NaN
#
#                                     TRB_antigen non_human_antigen  label
# P309-GACACGCGTGGTAACG-1-Liu_2025            NaN               NaN      0
# P309-AGCTTGATCGACAGCC-1-Liu_2025            NaN               NaN      0
# P309-GGGTTGCCAAATACAG-1-Liu_2025            NaN               NaN      0
# P25.ut.AGAGCGAAGCTAGTTC-1-Liu_2022          NaN               NaN      0
# CCCAATCTCGTCCGTT-1_PEM6C1-Chow_2023         NaN               NaN      0

# %%
depth_col = "total_counts"        # or your total count column
print("Depth Column:", depth_col)
print(adata.obs[depth_col].describe())
# Out:
# Depth Column: total_counts
# count    371010.000000
# mean       3566.198854
# std        1702.464599
# min         492.000000
# 25%        2462.000000
# 50%        3252.000000
# 75%        4251.000000
# max       20000.000000
# Name: total_counts, dtype: float64

# %%
from scipy.sparse import issparse
print("is sparse:", issparse(adata.X))

adata.layers["counts"] = adata.X.copy()

target_sum = 3000
d = adata.obs[depth_col].to_numpy()

scale = np.divide(target_sum, d, out=np.zeros_like(d, dtype=float), where=d>0)

if issparse(adata.X):
    X = adata.X.tocsr()
    adata.layers["norm"] = X.multiply(scale[:, None]).tocsr()
else:
    adata.layers["norm"] = adata.X * scale[:, None]

adata.X = adata.layers["norm"].copy()

sc.pp.log1p(adata)
print(adata.X.shape)
print(adata.X[:2, :4])
# Out:
# is sparse: True
# (371010, 6256)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2 stored elements and shape (2, 4)>
#   Coords	Values
#   (0, 0)	0.8513821034609452
#   (1, 0)	0.7041595747815715

# %% [markdown]
# ## Exploratory analysis
#
# This analysis is the same for any testing data and thus only need to do it for the first test data.

# %%
if(test_study == "Chen_2024"):
    sc.pp.highly_variable_genes(adata, n_top_genes=2000)
    adata_hvg = adata[:, adata.var["highly_variable"]].copy()
    sc.tl.pca(adata_hvg, n_comps=50, svd_solver="arpack", zero_center=False)
    sc.pp.neighbors(adata_hvg, n_neighbors=15, n_pcs=30, use_rep="X_pca")
    sc.tl.umap(adata_hvg, min_dist=0.3)

    sc.settings.set_figure_params(dpi=100, dpi_save=300, figsize=(6, 5))

    for col in [f"pos_score_{cell_type}", f"neg_score_{cell_type}"]:
        # copy the obs columns over if we sliced to HVGs (obs is preserved, so this is optional)
        assert col in adata_hvg.obs
        sc.pl.umap(
            adata_hvg,
            color=col,
            color_map="viridis",   # try "plasma", "magma", "turbo" if you prefer
            edges=False,
            frameon=False,
            save=f"figures/umap_{col}.png"
        )

    sc.pl.umap(
        adata_hvg,
        color="study",
        edges=False,
        frameon=False,
        save=f"figures/umap_study_{cell_type}.png"
    )

    sc.pl.umap(
        adata_hvg,
        color="Tissue",
        edges=False,
        frameon=False,
        save=f"figures/umap_tissue_{cell_type}.png"
    )

# %% [markdown]
# ## Classify cancer reactive or not using postive vs. negative score
#
# Simply run a logistic regression.

# %%
print(pd.crosstab(adata.obs["study"], adata.obs["label"]))

n_samples = ((adata.obs["study"] == test_study) & (adata.obs["label"] == 1)).sum()
print(f"Number of samples: {n_samples}")

if n_samples == 0:
    raise ValueError("No samples with label 1 from the test study.")
# Out:
# label            0      1
# study
# Chen_2024    46417  15762
# Chow_2023    17516   2545
# Liu_2022     21775   6725
# Liu_2025    139542  50427
# Zheng_2021   58290  12011
# Number of samples: 12011

# %%
from pandas.api.types import is_numeric_dtype
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc

pos_score_col = f"pos_score_{cell_type}"
neg_score_col = f"neg_score_{cell_type}"

req_cols = [pos_score_col, neg_score_col, 'label', 'study']
missing = [c for c in req_cols if c not in adata.obs.columns]
if missing:
    raise ValueError(f"Missing required columns in adata.obs: {missing}")

df = adata.obs[req_cols].copy().dropna(subset=req_cols)

# label must be numeric and only {0,1}
if not is_numeric_dtype(df['label']):
    raise ValueError(f"`label` must be numeric (0/1). Got dtype={df['label'].dtype}")
vals = set(np.unique(df['label'].values))
if not vals.issubset({0, 1}):
    raise ValueError(f"`label` must contain only 0 and 1. Found values: {sorted(vals)}")

# ---- 2) Split by study (test = test_study)
test_mask = (df['study'].astype(str) == test_study)
if not test_mask.any():
    raise ValueError(f"No rows with study == {test_study} for testing.")
if (~test_mask).sum() == 0:
    raise ValueError(f"All rows are {test_study}; need non–{test_study} rows for training.")

X_train = df.loc[~test_mask, [pos_score_col, neg_score_col]].to_numpy()
y_train = df.loc[~test_mask, 'label'].astype(int).to_numpy()

X_test  = df.loc[test_mask,  [pos_score_col, neg_score_col]].to_numpy()
y_test  = df.loc[test_mask,  'label'].astype(int).to_numpy()

# Both classes must be present in train; ROC needs positives in test
if np.unique(y_train).size < 2:
    raise ValueError("Training set must contain both classes 0 and 1.")
if (y_test == 1).sum() == 0 or (y_test == 0).sum() == 0:
    raise ValueError("Test set must contain both classes 0 and 1 to compute ROC/AUC.")

# ---- 3) Model: scale -> logistic regression
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=2000, class_weight='balanced', solver='lbfgs')),
])
pipe.fit(X_train, y_train)

# ---- 4) Predict + ROC/AUC 
y_score = pipe.predict_proba(X_test)[:, 1]  # prob of class 1
fpr, tpr, _ = roc_curve(y_test, y_score, pos_label=1)
roc_auc = auc(fpr, tpr)
print(f"AUC on {test_study}: {roc_auc:.4f}")

# ---- 5) Plot ROC
plt.figure(figsize=(5, 4), dpi=300)
plt.plot(fpr, tpr, label=f'ROC (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--', linewidth=1)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC — Logistic Regression (test: {test_study})')
plt.legend(loc='lower right')
plt.subplots_adjust(left=0.2)  # default is ~0.125
plt.savefig(f"figures/logistic_regression_roc_{cell_type}_{test_study}.png")
# Out:
# AUC on Zheng_2021: 0.9708

# %%
adata_sub = adata[adata.obs["study"] != test_study].copy()
adata_sub.obs["label"] = pd.Categorical(adata_sub.obs["label"].astype(str),
                                        categories=["0", "1"])

# (optional) sanity checks
assert (adata_sub.obs["label"] == "0").sum() > 0 and (adata_sub.obs["label"] == "1").sum() > 0
print(adata_sub.obs["label"].value_counts(dropna=False))
# Out:
# label
# 0    225250
# 1     75459
# Name: count, dtype: int64

# %%
# -----------------------------
# 1) Rank-sum DE: label==1 vs label==0
# -----------------------------
sc.tl.rank_genes_groups(
    adata_sub,
    groupby="label",
    groups=["1"],             # test group(s)
    reference="0",            # control group
    method="wilcoxon",
    corr_method="benjamini-hochberg",  # FDR
    use_raw=False,            # set True if you saved counts in .raw and want to test on raw
    n_genes=adata_sub.n_vars, # compute stats for all genes
    key_added="de_wilcoxon"
)

# -----------------------------
# 2) Collect results into a DataFrame
# -----------------------------
# For Scanpy >=1.9:
df_de = sc.get.rank_genes_groups_df(adata_sub, group="1", key="de_wilcoxon")
# Columns: ['names','scores','logfoldchanges','pvals','pvals_adj','pts','pts_rest']

# Sort by adjusted p-value (FDR)
df_de = df_de.sort_values("pvals_adj", ascending=True)

# Save full results and top 1000
df_de.to_csv(f"DE_results/DE_{cell_type}_test_study_{test_study}.csv", index=False)

# -----------------------------
# 3) Volcano plot
# -----------------------------
x = df_de["logfoldchanges"]                 # log2FC in Scanpy is natural-log FC; if you prefer log2, convert:
# If you want true log2 fold-change:
# x = df_de["logfoldchanges"] / np.log(2)

y = -np.log10(df_de["pvals_adj"].clip(lower=1e-300))

plt.figure(figsize=(6,5), dpi=150)
plt.scatter(x, y, s=8, alpha=0.5)

# Highlight top 1000 by FDR
is_top = df_de.index.isin(df_de.index[:1000])
plt.scatter(x[is_top], y[is_top], s=10, alpha=0.8)

# Reference lines (optional)
plt.axhline(-np.log10(0.05), linestyle="--", linewidth=1)
plt.axvline(0, linestyle=":", linewidth=1)

plt.xlabel("log fold change (1 vs 0)")      # note: natural log by default
plt.ylabel("-log10(FDR)")
plt.title(f"Wilcoxon DE: (excluding {test_study})")
plt.tight_layout()
plt.savefig(f"figures/volcano_{cell_type}_test_study_{test_study}.png")
plt.close()
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ### Prepare data splitting indices

# %%
print(test_study)
print(adata.obs.shape)
print(adata.obs['study'].value_counts())

print(adata.obs["label"].value_counts())
print(pd.crosstab(adata.obs["study"], adata.obs["label"]))

test_indices = np.where(adata.obs['study'] == test_study)[0]
train_val_indices = np.where(adata.obs['study'] != test_study)[0]
train_indices, val_indices = train_test_split(train_val_indices, test_size=validating_frac, 
                                              stratify=adata.obs['study'][train_val_indices], 
                                              random_state=42)
print("Length of train_indices:", len(train_indices))
print("Length of validation_indices:", len(val_indices))
print("Length of test_indices:", len(test_indices))
# Out:
# Zheng_2021
# (371010, 45)
# study
# Liu_2025      189969
# Zheng_2021     70301
# Chen_2024      62179
# Liu_2022       28500
# Chow_2023      20061
# Name: count, dtype: int64
# label
# 0    283540
# 1     87470
# Name: count, dtype: int64
# label            0      1
# study
# Chen_2024    46417  15762
# Chow_2023    17516   2545
# Liu_2022     21775   6725
# Liu_2025    139542  50427
# Zheng_2021   58290  12011
# Length of train_indices: 270638
# Length of validation_indices: 30071
# Length of test_indices: 70301
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/1704601559.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   stratify=adata.obs['study'][train_val_indices],

# %% [markdown]
# ### Split traning test data

# %%
top_genes = df_de.sort_values("pvals").head(1000)["names"].tolist()
print(top_genes[:10])

adata_top1000 = adata[:, top_genes]
X = adata_top1000.X.toarray()
print(X.shape)
# Out:
# ['GZMB', 'HLA-DRB1', 'LAG3', 'LSP1', 'GZMH', 'CTLA4', 'NKG7', 'CCL5', 'DUSP4', 'GZMA']
# (371010, 1000)

# %%
# Split the data into training, validation, and testing sets
trainX = X[train_indices]
valX = X[val_indices]
testX = X[test_indices]

trainY = adata.obs["label"][train_indices]
valY   = adata.obs["label"][val_indices]
testY  = adata.obs["label"][test_indices]

print("Training Data:")
print(trainX.shape)
print(trainY.shape)
print()

print("Validation Data:")
print(valX.shape)
print(valY.shape)
print()

print("Testing Data:")
print(testX.shape)
print(testY.shape)
print()

print('trainX[0:2, 0:4]:')
print(trainX[0:2, 0:4])
print()

print('trainY[0:2]:')
print(trainY[0:2])
print()

print('valX[0:2, 0:4]:')
print(valX[0:2, 0:4])
print()

print('valY[0:2]:')
print(valY[0:2])
print()

print('testX[0:2, 0:4]:')
print(testX[0:2, 0:4])
print()

print('testY[0:2]:')
print(testY[0:2])
print()
# Out:
# Training Data:
# (270638, 1000)
# (270638,)
#
# Validation Data:
# (30071, 1000)
# (30071,)
#
# Testing Data:
# (70301, 1000)
# (70301,)
#
# trainX[0:2, 0:4]:
# [[0.85099743 1.10292713 0.         0.85099743]
#  [3.06783445 0.61732981 1.48520801 1.27029773]]
#
# trainY[0:2]:
# P587-CGAACATGTAGAGGAA-1-Liu_2025    0
# P5-CCGTACTCATCTATGG-1-Liu_2025      1
# Name: label, dtype: int64
#
# valX[0:2, 0:4]:
# [[0.         0.         0.         0.6865465 ]
#  [0.63087261 2.08368224 0.63087261 0.63087261]]
#
# valY[0:2]:
# P470-CGATGTAGTTCAGACT-1-Liu_2025    0
# P146-AAAGATGAGACGACGT-1-Liu_2025    1
# Name: label, dtype: int64
#
# testX[0:2, 0:4]:
# [[2.34005097 0.         0.         0.89336946]
#  [1.34417017 0.         0.75799868 1.60321941]]
#
# testY[0:2]:
# ACTTGTTGTTAAGACA.66-THCA-Zheng_2021    0
# CCACCTACATTGCGGC.66-THCA-Zheng_2021    0
# Name: label, dtype: int64
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/3945436047.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   trainY = adata.obs["label"][train_indices]
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/3945436047.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   valY   = adata.obs["label"][val_indices]
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/3945436047.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   testY  = adata.obs["label"][test_indices]

# %% [markdown]
# ## Set up model

# %%
# Parameters
input_dim = trainX.shape[1]
encoding_dim = bottle_size  # Bottleneck layer size

# Input layer
input = Input(shape=(input_dim,))

# Encoder
encoded = Dense(encode_layers[0], activation='relu')(input)
for i in range(len(encode_layers)-1):
  encoded = Dense(encode_layers[i+1], activation='relu')(encoded)
bottleneck = Dense(encoding_dim, activation='relu')(encoded)  # Latent space (bottleneck)

# Decoder
decoded = Dense(32, activation='relu')(bottleneck)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(input_dim, activation='relu', name='reconstruction')(decoded)  # Output layer (reconstructed input)

# Classification layer on top of the bottleneck
if len(classify_layers)==0:
  classifier_output = Dense(1, activation='sigmoid',name='classification')(bottleneck)
else:
  layer = Dense(size, activation='relu')(bottleneck)
  for i in range(len(classify_layers)-1):
    layer = Dense(classify_layers[i+1], activation='relu')(layer)
  classifier_output = Dense(1, activation='sigmoid',name='classification')(layer)

# Full model (Autoencoder + Classification)
full_model = Model(inputs = input, outputs = {"reconstruction": decoded, "classification": classifier_output})
full_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    128,128 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      4,128 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 8)         │        264 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │        288 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │      4,224 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification      │ (None, 1)         │          9 │ dense_2[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reconstruction      │ (None, 1000)      │    129,000 │ dense_4[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 266,041 (1.01 MB)
#  Trainable params: 266,041 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train the model

# %%
reconstruction_weight = 1.0  # Weight for reconstruction loss
classification_weight = 1.0  # Weight for classification loss

# %%
# Compile the model
def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1))

lr_scheduler = LearningRateScheduler(scheduler)

adam1 = optimizers.Adam(learning_rate=learn_rate)

full_model.compile(
	optimizer=adam1,
	loss={'reconstruction':'mean_absolute_error',
	      'classification':'binary_crossentropy'},  # Two losses: MAE for reconstruction, BCE for classification
	metrics={'reconstruction': 'mean_absolute_error','classification': 'accuracy'}, 
	loss_weights = {
			 'reconstruction':reconstruction_weight,
			 'classification':classification_weight
             }
)

#early stopping
early_stopping = EarlyStopping(
    monitor='val_classification_accuracy',  # Metric to monitor
    patience=model_patience,                # Number of epochs to wait
    restore_best_weights=True, 
    mode='max'
)

# %%
history = full_model.fit(
    x=trainX, 
    y={"reconstruction": trainX, "classification": trainY},
    epochs=max_epochs,
    batch_size=batch_size, 
    verbose=2,
    validation_data=(valX, {"reconstruction": valX, "classification": valY}),
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Epoch 1/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9481 - classification_loss: 0.1259 - loss: 0.4253 - reconstruction_loss: 0.2993 - reconstruction_mean_absolute_error: 0.2993 - val_classification_accuracy: 0.9638 - val_classification_loss: 0.0889 - val_loss: 0.3788 - val_reconstruction_loss: 0.2899 - val_reconstruction_mean_absolute_error: 0.2899 - learning_rate: 0.0010
# Epoch 2/20
# 8458/8458 - 16s - 2ms/step - classification_accuracy: 0.9638 - classification_loss: 0.0907 - loss: 0.3784 - reconstruction_loss: 0.2878 - reconstruction_mean_absolute_error: 0.2878 - val_classification_accuracy: 0.9652 - val_classification_loss: 0.0900 - val_loss: 0.3760 - val_reconstruction_loss: 0.2860 - val_reconstruction_mean_absolute_error: 0.2860 - learning_rate: 0.0010
# Epoch 3/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9689 - classification_loss: 0.0793 - loss: 0.3645 - reconstruction_loss: 0.2851 - reconstruction_mean_absolute_error: 0.2851 - val_classification_accuracy: 0.9632 - val_classification_loss: 0.0974 - val_loss: 0.3824 - val_reconstruction_loss: 0.2850 - val_reconstruction_mean_absolute_error: 0.2850 - learning_rate: 0.0010
# Epoch 4/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9724 - classification_loss: 0.0710 - loss: 0.3553 - reconstruction_loss: 0.2843 - reconstruction_mean_absolute_error: 0.2843 - val_classification_accuracy: 0.9638 - val_classification_loss: 0.1042 - val_loss: 0.3883 - val_reconstruction_loss: 0.2841 - val_reconstruction_mean_absolute_error: 0.2841 - learning_rate: 0.0010
# Epoch 5/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9751 - classification_loss: 0.0638 - loss: 0.3476 - reconstruction_loss: 0.2838 - reconstruction_mean_absolute_error: 0.2838 - val_classification_accuracy: 0.9626 - val_classification_loss: 0.1086 - val_loss: 0.3923 - val_reconstruction_loss: 0.2837 - val_reconstruction_mean_absolute_error: 0.2837 - learning_rate: 0.0010
# Epoch 6/20
# 8458/8458 - 16s - 2ms/step - classification_accuracy: 0.9776 - classification_loss: 0.0579 - loss: 0.3412 - reconstruction_loss: 0.2833 - reconstruction_mean_absolute_error: 0.2833 - val_classification_accuracy: 0.9634 - val_classification_loss: 0.1108 - val_loss: 0.3942 - val_reconstruction_loss: 0.2834 - val_reconstruction_mean_absolute_error: 0.2834 - learning_rate: 0.0010
# Epoch 7/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9801 - classification_loss: 0.0523 - loss: 0.3354 - reconstruction_loss: 0.2830 - reconstruction_mean_absolute_error: 0.2830 - val_classification_accuracy: 0.9644 - val_classification_loss: 0.1213 - val_loss: 0.4045 - val_reconstruction_loss: 0.2833 - val_reconstruction_mean_absolute_error: 0.2832 - learning_rate: 0.0010
# Epoch 8/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9819 - classification_loss: 0.0475 - loss: 0.3305 - reconstruction_loss: 0.2830 - reconstruction_mean_absolute_error: 0.2830 - val_classification_accuracy: 0.9589 - val_classification_loss: 0.1600 - val_loss: 0.4435 - val_reconstruction_loss: 0.2835 - val_reconstruction_mean_absolute_error: 0.2835 - learning_rate: 0.0010
# Epoch 9/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9838 - classification_loss: 0.0434 - loss: 0.3264 - reconstruction_loss: 0.2830 - reconstruction_mean_absolute_error: 0.2830 - val_classification_accuracy: 0.9646 - val_classification_loss: 0.1288 - val_loss: 0.4124 - val_reconstruction_loss: 0.2835 - val_reconstruction_mean_absolute_error: 0.2835 - learning_rate: 0.0010
# Epoch 10/20
# 8458/8458 - 16s - 2ms/step - classification_accuracy: 0.9849 - classification_loss: 0.0401 - loss: 0.3214 - reconstruction_loss: 0.2812 - reconstruction_mean_absolute_error: 0.2812 - val_classification_accuracy: 0.9629 - val_classification_loss: 0.1352 - val_loss: 0.4161 - val_reconstruction_loss: 0.2808 - val_reconstruction_mean_absolute_error: 0.2808 - learning_rate: 0.0010
# Epoch 11/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9866 - classification_loss: 0.0359 - loss: 0.3159 - reconstruction_loss: 0.2799 - reconstruction_mean_absolute_error: 0.2799 - val_classification_accuracy: 0.9625 - val_classification_loss: 0.1517 - val_loss: 0.4313 - val_reconstruction_loss: 0.2796 - val_reconstruction_mean_absolute_error: 0.2796 - learning_rate: 9.0484e-04
# Epoch 12/20
# 8458/8458 - 17s - 2ms/step - classification_accuracy: 0.9879 - classification_loss: 0.0326 - loss: 0.3121 - reconstruction_loss: 0.2795 - reconstruction_mean_absolute_error: 0.2795 - val_classification_accuracy: 0.9611 - val_classification_loss: 0.1640 - val_loss: 0.4435 - val_reconstruction_loss: 0.2795 - val_reconstruction_mean_absolute_error: 0.2795 - learning_rate: 8.1873e-04

# %%
name = cell_type
name += "_" + test_study
name += "_learn_rate_" + str(learn_rate)
name += "_batch_size_" + str(batch_size)
name += "_cla_weight_" + str(classification_weight)
name += "_rec_weight_" + str(reconstruction_weight)
if model_patience >= max_epochs:
  name += "_epochs_" + str(max_epochs)
else:
  name += "_max_epochs_" + str(max_epochs)

print(name)

path = os.path.join(results_dir, name)
if not os.path.exists(path):
  os.makedirs(path)
# Out:
# CD8_Zheng_2021_learn_rate_0.001_batch_size_32_cla_weight_1.0_rec_weight_1.0_max_epochs_20

# %%
plt.style.use("ggplot")
plt.figure(figsize=(4, 3), dpi=300)

plt.plot(history.history['reconstruction_loss'], label='Reconstruction (MAE)', color='tab:blue')
plt.plot(history.history['classification_loss'], label='Classification (BCE)', color='tab:orange')

plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.subplots_adjust(left=0.2, right=0.98, top=0.98, bottom=0.2)
plt.savefig(f"{path}/classification_loss_plot.png")
plt.close()

plt.style.use("ggplot")
plt.figure(figsize=(4, 3), dpi=300)
plt.plot(history.history['val_reconstruction_loss'], label='Reconstruction (MAE)', color='tab:blue')
plt.plot(history.history['val_classification_loss'], label='Classification (BCE)', color='tab:orange')

plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.subplots_adjust(left=0.2, right=0.98, top=0.98, bottom=0.2)
plt.savefig(f"{path}/val_classification_loss_plot.png")
plt.close()

plot_classification(history, 1, f"{path}/classification_accuracy_plot.png")
table_save_classification(history, 1, f"{path}/classification_accuracy_table.txt")

# %% [markdown]
# # Make predictin using test data

# %%
prediction = full_model.predict(testX)["classification"].flatten()
print(testY)

# Create a DataFrame with two columns: 'Prediction' and 'True Label'
df = pd.DataFrame({
    'Prediction': prediction,
    'True Label': testY
})

# Show the DataFrame
print(df)
# Out:
#    1/2197 ━━━━━━━━━━━━━━━━━━━━ 57s 26ms/step
#  116/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step
#  117/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step
#  247/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
#  380/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
#  381/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step
#  510/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step
#  642/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step
#  775/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
#  776/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
#  909/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 1043/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
# 1176/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 1309/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 1310/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step
# 1436/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 1568/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 1696/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step
# 1819/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# 1944/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
# 2066/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
# 2190/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1s 399us/step
# ACTTGTTGTTAAGACA.66-THCA-Zheng_2021    0
# CCACCTACATTGCGGC.66-THCA-Zheng_2021    0
# GACGGCTTCAGTTAGC.66-THCA-Zheng_2021    0
# GCACTCTAGCTAACTC.66-THCA-Zheng_2021    0
# GTGCAGCCAGTCTTCC.66-THCA-Zheng_2021    0
#                                       ..
# TCTTCGGTCACAATGC.80-UCEC-Zheng_2021    0
# TTGCGTCCACACCGAC.80-UCEC-Zheng_2021    0
# TTGGAACAGTGGTCCC.79-UCEC-Zheng_2021    0
# TTTATGCAGATATGCA.79-UCEC-Zheng_2021    0
# GCTGCTTTCCGAGCCA.68-THCA-Zheng_2021    0
# Name: label, Length: 70301, dtype: int64
#                                        Prediction  True Label
# ACTTGTTGTTAAGACA.66-THCA-Zheng_2021  7.157638e-04           0
# CCACCTACATTGCGGC.66-THCA-Zheng_2021  4.296717e-03           0
# GACGGCTTCAGTTAGC.66-THCA-Zheng_2021  7.780880e-02           0
# GCACTCTAGCTAACTC.66-THCA-Zheng_2021  4.882242e-03           0
# GTGCAGCCAGTCTTCC.66-THCA-Zheng_2021  5.935697e-02           0
# ...                                           ...         ...
# TCTTCGGTCACAATGC.80-UCEC-Zheng_2021  9.891015e-01           0
# TTGCGTCCACACCGAC.80-UCEC-Zheng_2021  9.413726e-01           0
# TTGGAACAGTGGTCCC.79-UCEC-Zheng_2021  7.383997e-01           0
# TTTATGCAGATATGCA.79-UCEC-Zheng_2021  1.372556e-01           0
# GCTGCTTTCCGAGCCA.68-THCA-Zheng_2021  7.881533e-10           0
#
# [70301 rows x 2 columns]

# %% [markdown]
# ## Summarize results
# ### Boxplot

# %%
plt.figure(figsize=(3, 3), facecolor='white')
sns.boxplot(x='True Label', y='Prediction', data=df)
plt.subplots_adjust(left=0.25, bottom=0.2)

ax = plt.gca()
ax.set_facecolor('none')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')

plt.savefig(f'{path}/test_box_plot_predictions.pdf', format='pdf')
plt.show()

df.to_csv(f"{path}/predictions_test_data.txt", sep='\t', index=True)
# Out:
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/1930487193.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### ROC curve

# %%
# Calculate the ROC curve
fpr, tpr, _ = roc_curve(df['True Label'], df['Prediction'])

# Calculate the AUC
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(3, 3), facecolor='white')
plt.plot(fpr, tpr, color='orange', lw=2)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([-0.02, 1.0])
plt.ylim([-0.02, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'AUC = {roc_auc:.3f}')

ax = plt.gca()
ax.set_facecolor('none')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')

plt.subplots_adjust(left=0.25, bottom=0.2)

# Save the plot
plt.savefig(f"{path}/roc_curve.pdf", format='pdf')

# Show the plot
plt.show()
# Out:
# /var/folders/fk/gk1pvdpx7fz79tx26t0rjc7c0000gp/T/ipykernel_30697/2507533787.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
